# %%
import h5py
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
preds = '/Seg_experiments/experiments/bony_labyrinth_dataset/segmentation/UNet/lr_0.001/Predictions/epoch_0.h5'

# %%
data = h5py.File(preds)

# %%
data.keys()
# Out:
# <KeysViewHDF5 ['input', 'predicted_seg', 'target_seg']>

# %%
input = np.array(data['input'])
target = np.array(data['target_seg'])
output = np.array(data['predicted_seg'])

# %%
input.shape
# Out:
# (1, 1, 256, 256)

# %%
plt.imshow(input[0,0,:,:])

# %%
plt.imshow(target[0,0,:,:])

# %%
plt.imshow(output[0,0,:,:])
